# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load the Data - import the necessary libraries (e.g., Pandas) 
# to read your data from a file (e.g., CSV) or a database.

df = pd.read_csv('C:/Users/user/Desktop/ITD105 Files/EDA/Datasets_Missing/missing_car_evaluation_classification.csv')

# %%
# 2. Basic Data Exploration - Check the first few rows of the dataset 
# to get an initial sense of the data's structure.

df.head()
# Out:
#   Buying Price Maintenance Cost Number of Doors Number of Persons Lug_Boot  \
# 0        vhigh            vhigh               2                 2    small
# 1        vhigh            vhigh               2                 2    small
# 2        vhigh            vhigh               2                 2    small
# 3        vhigh            vhigh               2                 2      med
# 4        vhigh            vhigh               2                 2      med
#
#   Safety Classification
# 0    low          unacc
# 1    med          unacc
# 2   high          unacc
# 3    low          unacc
# 4    med          unacc

# %%
# 3. Data Summary - Generate descriptive statistics for the data, including mean, median, 
# standard deviation, and quartiles, to understand the central tendency and spread of the data.

df.describe()
# Out:
#        Buying Price Maintenance Cost Number of Doors Number of Persons  \
# count          1728             1728            1728              1728
# unique            4                4               4                 3
# top           vhigh            vhigh               2                 2
# freq            432              432             432               576
#
#        Lug_Boot Safety Classification
# count      1728   1728           1728
# unique        3      3              4
# top       small    low          unacc
# freq        576    576           1210

# %%
#4. Data Information - check the data types of each column, 
# the number of non-null values, and memory usage.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Buying Price       1728 non-null   object
#  1   Maintenance Cost   1728 non-null   object
#  2   Number of Doors    1728 non-null   object
#  3   Number of Persons  1728 non-null   object
#  4   Lug_Boot           1728 non-null   object
#  5   Safety             1728 non-null   object
#  6   Classification     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
# 5. Handling Missing Data - identify and handle missing values using techniques 
# like imputation or removal.
# Check for missing values in the dataset
missing_values = df.isnull().sum()

# Display the columns with missing values and their respective counts
print("Columns with Missing Values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with Missing Values:
# Series([], dtype: int64)

# %%
# Fill Missing Values
# Fill missing values with the mode (most frequent value) for each column
df = df.fillna(df.mode().iloc[0])

# Display the DataFrame with missing values filled
print(df)
# Out:
#      Buying Price Maintenance Cost Number of Doors Number of Persons Lug_Boot  \
# 0           vhigh            vhigh               2                 2    small
# 1           vhigh            vhigh               2                 2    small
# 2           vhigh            vhigh               2                 2    small
# 3            high             high               3              more    small
# 4            high             high               3              more    small
# ...           ...              ...             ...               ...      ...
# 1723          low              low           5more              more      med
# 1724          low              low           5more              more      med
# 1725          low              low           5more              more      big
# 1726          low              low           5more              more      big
# 1727          low              low           5more              more      big
#
#      Safety Classification
# ...

# %%
# Check for missing values after Fillna
# Check for missing values in the dataset
missing_values_after = df.isnull().sum()

# Display the columns with missing values and their respective counts
print("Columns with Missing Values:")
print(missing_values_after[missing_values_after > 0])
# Out:
# Columns with Missing Values:
# Series([], dtype: int64)

# %%
# 6. Feature Engineering (if needed) - is the process of creating new features or 
# modifying existing ones to improve the performance of machine learning

# %%
# 7. Data Visualization - Create visualizations to explore data distributions, relationships, and patterns. 
#Use libraries like Matplotlib and Seaborn.

#a. Univariate plots focus on a single variable or feature at a time. 
#They are used to visualize the distribution and characteristics of individual variables in isolation.

#Bar Graph
# Assuming 'Classification' is the column with class labels in your DataFrame 'df'
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

# Create a count plot for the 'Classification' variable
sns.countplot(data=df, x='Classification')
plt.title('Distribution of Classes')
plt.xlabel('Class')
plt.ylabel('Count')

plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.show()

# %%
# Bar Plot 2
# Assuming 'Buying Price' is a column in your DataFrame 'df'
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

# Create a bar plot for 'Buying Price'
sns.countplot(data=df, x='Buying Price')
plt.title('Distribution of Buying Price')
plt.xlabel('Buying Price')
plt.ylabel('Count')

plt.xticks(rotation=45)
plt.show()

# %%
# Line Plots
classification_counts = df['Classification'].value_counts()

# Create a line plot (density-like plot)
sns.lineplot(x=classification_counts.index, y=classification_counts.values)

# Customize the plot
plt.title('Density-Like Plot of Car Classifications')
plt.xlabel('Classification')
plt.ylabel('Density (Count / Total Count)')

# Show the plot
plt.xticks(rotation=45)
plt.show()

# %%
# Box and Whisker Plots
sns.boxplot(x='Classification', data=df)

# Customize the plot
plt.title('Box and Whisker Plot of Car Classifications')
plt.xlabel('Classification')
plt.ylabel('Values')

# Show the plot
plt.xticks(rotation=45)
plt.show()

# %%
#Multivariate plots involve the simultaneous visualization of two or more variables to explore relationships, 
# correlations, and patterns among them.

# Create a DataFrame
df = pd.read_csv('C:/Users/user/Desktop/ITD105 Files/EDA/Datasets/car_evaluation_classification.csv')

# Create a count plot for the 'Buying Price' variable with 'Classification' as hue
plt.figure(figsize=(10, 6))
sns.countplot(x='Buying Price', hue='Classification', data=df)
plt.title('Count Plot of Buying Price by Classification')
plt.xlabel('Buying Price')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#Buying Price and Maintenance Cost

# Create a DataFrame
df = pd.read_csv('C:/Users/user/Desktop/ITD105 Files/EDA/Datasets/car_evaluation_classification.csv')

# Create a grouped bar plot to compare counts of car classifications by Buying Price and Maintenance Cost
plt.figure(figsize=(10, 6))
sns.countplot(x='Buying Price', hue='Maintenance Cost', data=df)
plt.title('Counts of Car Classifications by Buying Price and Maintenance Cost')
plt.xlabel('Buying Price')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Maintenance Cost')
plt.show()

# %%
# 8. Identifying and Handling Outliers (If needed)
# Calculate frequency counts for the "Buying Price" column
buying_price_counts = df['Buying Price'].value_counts()

# Get the total count of data points
total_count = buying_price_counts.sum()

# Create a bar plot to visualize the counts
plt.figure(figsize=(10, 6))
sns.lineplot(x=buying_price_counts.index, y=buying_price_counts.values, label='Frequency Counts')
plt.title('Frequency Counts of Buying Price Categories')
plt.xlabel('Buying Price')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add a legend with the total count and counts of 'med', 'low', 'high', 'vhigh'
legend_text = f'Total Count: {total_count}, med: {buying_price_counts["med"]}, low: {buying_price_counts["low"]}, high: {buying_price_counts["high"]}, vhigh: {buying_price_counts["vhigh"]}, 69: {buying_price_counts["69"]}'
plt.legend([legend_text])

plt.show()

# %%
# Handle Outlier
mode_buying_price = df['Buying Price'].mode().values[0]
print("Mode of Buying Price:", mode_buying_price)
count = df['Buying Price'].value_counts().get("69", 0)
print("Count of '69' in Buying Price:", count_69)
# Out:
# Mode of Buying Price: high
# Count of '69' in Buying Price: 2

# %%
# Handle Outlier 2
# Identify and handle the 69 outlier
outlier_value = "high"  # Replace with your choice of value
df['Buying Price'] = df['Buying Price'].replace("69", outlier_value)

# %%
# Check Outlier
count_69_after_filling = df['Buying Price'].value_counts().get("69", 0)
print("Count of '69' in Buying Price after Filling:", count_69_after_filling)
# Out:
# Count of '69' in Buying Price after Filling: 0

# %% [markdown]
# # 9. Summary and Insights
# 1.Dataset Overview:
# Number of Data Points: 1,728
# Number of Features: 7
# Data Types: All features in the dataset are categorical with the object data type.
#
# 2.Features:
# Buying Price: Represents the buying price category of the car (e.g., vhigh, high, med, low).
# Maintenance Cost: Indicates the maintenance cost category (e.g., vhigh, high, med, low).
# Number of Doors: Specifies the number of doors (e.g., 2, 3, 4, 5more).
# Number of Persons: Indicates the number of persons the car can accommodate (e.g., 2, 4, more).
# Lug_Boot: Represents the size of the luggage boot (e.g., small, med, big).
# Safety: Indicates the safety level of the car (e.g., low, med, high).
# Classification: Represents the evaluation of the car (e.g., unacc, acc, good, vgood).
#
# 3.Data Insights:
# Buying Price and Maintenance Cost: These attributes categorize the cost-related aspects of the car. They are essential for potential car buyers who have budget constraints. Understanding these attributes can help individuals make informed decisions based on their financial limitations.
# Number of Doors and Number of Persons: These attributes determine the car's seating capacity and accessibility. They can help customers choose a car that suits their needs, such as accommodating more people or offering greater accessibility.
# Lug_Boot: The luggage boot size is important for those who require storage space for their belongings. It can influence the choice of the car based on transportation needs.
# Safety: Safety is a paramount concern for car buyers. It's crucial to evaluate the safety level when considering a car purchase.
# Classification: This feature provides the evaluation of the car. It summarizes the car's overall quality and is valuable for individuals seeking to understand the car's performance and reliability.
#
# 4.Data Quality: The dataset does contain missing values and outliers, but the missing values are being filled and the outliers are being handled.
